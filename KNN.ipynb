# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from statistics_helper import StatisticsHelper

#Load the data
full_employee_data: pd.DataFrame = pd.read_csv('full_employee_data_cleaned.csv')

#Prepare the data
target_column = 'Attrition'
#Replace 'target_column' with the actual name of the target column
X = full_employee_data.drop(target_column, axis=1)
y = full_employee_data[target_column]

#Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True, random_state=42)

# %%
#Test for the best n_neighbors value
for i in range(1,20):
    rf_model = KNeighborsClassifier(n_neighbors=i)
    rf_model.fit(X_train, y_train)

    #Make predictions
    y_pred = rf_model.predict(X_test)
    stats_helper = StatisticsHelper(X, y, rf_model, y_test, y_pred)
    print(f"N = {i}")
    stats_helper.show_accuracy()
    stats_helper.show_cross_val_score()
    stats_helper.show_roc_auc_score()
# Out:
# N = 1
# ---- Accuracy ----
# Accuracy: 0.9965986394557823
# ------------------
# --- Cross Validation Scores ---
# Cross-validated scores: [1. 1. 1. 1. 1.]
# Mean accuracy: 1.0
# Standard deviation: 0.0
# -------------------------------
# ---- ROC AUC Score ----
# ROC AUC Score: 0.9893617021276595
# ------------------------
# N = 2
# ---- Accuracy ----
# Accuracy: 0.9591836734693877
# ------------------
# --- Cross Validation Scores ---
# Cross-validated scores: [1. 1. 1. 1. 1.]
# Mean accuracy: 1.0
# Standard deviation: 0.0
# -------------------------------
# ---- ROC AUC Score ----
# ROC AUC Score: 0.8723404255319149
# ------------------------
# N = 3
# ---- Accuracy ----
# Accuracy: 0.9467120181405896
# ------------------
# --- Cross Validation Scores ---
# Cross-validated scores: [1. 1. 1. 1. 1.]
# Mean accuracy: 1.0
# Standard deviation: 0.0
# -------------------------------
# ---- ROC AUC Score ----
# ROC AUC Score: 0.8706606942889136
# ------------------------
# N = 4
# ---- Accuracy ----
# Accuracy: 0.8639455782312925
# ------------------
# --- Cross Validation Scores ---
# Cross-validated scores: [0.88548753 0.87641723 0.86961451 0.87868481 0.88662132]
# Mean accuracy: 0.8793650793650795
# Standard deviation: 0.006234796863885488
# -------------------------------
# ---- ROC AUC Score ----
# ROC AUC Score: 0.5974387687713556
# ------------------------
# N = 5
# ---- Accuracy ----
# Accuracy: 0.844671201814059
# ------------------
# --- Cross Validation Scores ---
# Cross-validated scores: [0.8707483  0.85147392 0.83786848 0.84013605 0.87188209]
# Mean accuracy: 0.8544217687074831
# Standard deviation: 0.01454785934906615
# -------------------------------
# ---- ROC AUC Score ----
# ROC AUC Score: 0.6290378154879834
# ------------------------
# N = 6
# ---- Accuracy ----
# Accuracy: 0.8560090702947846
# ------------------
# --- Cross Validation Scores ---
# Cross-validated scores: [0.86281179 0.86281179 0.85941043 0.85827664 0.87868481]
# Mean accuracy: 0.8643990929705216
# Standard deviation: 0.007368742317130139
# -------------------------------
# ---- ROC AUC Score ----
# ROC AUC Score: 0.6042007637752319
# ------------------------
# N = 7
# ---- Accuracy ----
# Accuracy: 0.8707482993197279
# ------------------
# --- Cross Validation Scores ---
# Cross-validated scores: [0.86961451 0.87641723 0.86281179 0.85941043 0.87528345]
# Mean accuracy: 0.8687074829931973
# Standard deviation: 0.006703739455371662
# -------------------------------
# ---- ROC AUC Score ----
# ROC AUC Score: 0.6675280673041032
# ------------------------
# N = 8
# ---- Accuracy ----
# Accuracy: 0.8560090702947846
# ------------------
# --- Cross Validation Scores ---
# Cross-validated scores: [0.861678   0.85487528 0.85941043 0.85260771 0.86507937]
# Mean accuracy: 0.8587301587301589
# Standard deviation: 0.0045124146807556595
# -------------------------------
# ---- ROC AUC Score ----
# ROC AUC Score: 0.6013294283171102
# ------------------------
# N = 9
# ---- Accuracy ----
# Accuracy: 0.854875283446712
# ------------------
# --- Cross Validation Scores ---
# Cross-validated scores: [0.85827664 0.85487528 0.85147392 0.84807256 0.86281179]
# Mean accuracy: 0.8551020408163265
# Standard deviation: 0.005140945146827493
# -------------------------------
# ---- ROC AUC Score ----
# ROC AUC Score: 0.6207540126913028
# ------------------------
# N = 10
# ---- Accuracy ----
# Accuracy: 0.8503401360544217
# ------------------
# --- Cross Validation Scores ---
# Cross-validated scores: [0.85034014 0.85260771 0.85147392 0.8446712  0.86394558]
# Mean accuracy: 0.8526077097505669
# Standard deviation: 0.0062922616442229375
# -------------------------------
# ---- ROC AUC Score ----
# ROC AUC Score: 0.5864702673213312
# ------------------------
# N = 11
# ---- Accuracy ----
# Accuracy: 0.8503401360544217
# ------------------
# --- Cross Validation Scores ---
# Cross-validated scores: [0.85034014 0.85487528 0.84920635 0.84353741 0.86507937]
# Mean accuracy: 0.852607709750567
# Standard deviation: 0.007206461941982185
# -------------------------------
# ---- ROC AUC Score ----
# ROC AUC Score: 0.5979556091538174
# ------------------------
# N = 12
# ---- Accuracy ----
# Accuracy: 0.8537414965986394
# ------------------
# --- Cross Validation Scores ---
# Cross-validated scores: [0.85147392 0.85714286 0.85034014 0.84126984 0.85827664]
# Mean accuracy: 0.8517006802721088
# Standard deviation: 0.006059133431241443
# -------------------------------
# ---- ROC AUC Score ----
# ROC AUC Score: 0.5712665460705775
# ------------------------
# N = 13
# ---- Accuracy ----
# Accuracy: 0.8503401360544217
# ------------------
# --- Cross Validation Scores ---
# Cross-validated scores: [0.85034014 0.85827664 0.84580499 0.83786848 0.86281179]
# Mean accuracy: 0.8510204081632653
# Standard deviation: 0.008858061217516835
# -------------------------------
# ---- ROC AUC Score ----
# ROC AUC Score: 0.5864702673213312
# ------------------------
# N = 14
# ---- Accuracy ----
# Accuracy: 0.8503401360544217
# ------------------
# --- Cross Validation Scores ---
# Cross-validated scores: [0.85034014 0.85487528 0.84580499 0.84353741 0.85147392]
# Mean accuracy: 0.8492063492063492
# Standard deviation: 0.0040563591428567575
# -------------------------------
# ---- ROC AUC Score ----
# ROC AUC Score: 0.5663709191144802
# ------------------------
# N = 15
# ---- Accuracy ----
# Accuracy: 0.8526077097505669
# ------------------
# --- Cross Validation Scores ---
# Cross-validated scores: [0.85147392 0.8537415  0.84580499 0.84353741 0.85260771]
# Mean accuracy: 0.8494331065759637
# Standard deviation: 0.004018150826909129
# -------------------------------
# ---- ROC AUC Score ----
# ROC AUC Score: 0.5792057886122836
# ------------------------
# N = 16
# ---- Accuracy ----
# Accuracy: 0.8537414965986394
# ------------------
# --- Cross Validation Scores ---
# Cross-validated scores: [0.85600907 0.85147392 0.85034014 0.84807256 0.85260771]
# Mean accuracy: 0.8517006802721088
# Standard deviation: 0.002624906327163312
# -------------------------------
# ---- ROC AUC Score ----
# ROC AUC Score: 0.5569098687799696
# ------------------------
# N = 17
# ---- Accuracy ----
# Accuracy: 0.8492063492063492
# ------------------
# --- Cross Validation Scores ---
# Cross-validated scores: [0.85034014 0.85260771 0.84693878 0.84807256 0.85487528]
# Mean accuracy: 0.8505668934240364
# Standard deviation: 0.0029039112187903976
# -------------------------------
# ---- ROC AUC Score ----
# ROC AUC Score: 0.5542108134493353
# ------------------------
# N = 18
# ---- Accuracy ----
# Accuracy: 0.8514739229024944
# ------------------
# --- Cross Validation Scores ---
# Cross-validated scores: [0.84580499 0.84920635 0.85147392 0.84580499 0.85034014]
# Mean accuracy: 0.8485260770975056
# Standard deviation: 0.0023346100092941106
# -------------------------------
# ---- ROC AUC Score ----
# ROC AUC Score: 0.5469463347402876
# ------------------------
# N = 19
# ---- Accuracy ----
# Accuracy: 0.8492063492063492
# ------------------
# --- Cross Validation Scores ---
# Cross-validated scores: [0.8446712  0.85600907 0.84920635 0.84920635 0.85034014]
# Mean accuracy: 0.8498866213151928
# Standard deviation: 0.0036281179138321924
# -------------------------------
# ---- ROC AUC Score ----
# ROC AUC Score: 0.5513394779912137
# ------------------------

# %% [markdown]
# It can be seen from the results above that N = 1,2,3 has the best results but is not reliable in a more varied dataset as it basically just picks the number next to it. N = 7 appears to reach a good result among the rest so that is that we will be using.

# %%
rf_model = KNeighborsClassifier(n_neighbors=7)
rf_model.fit(X_train, y_train)

# Make predictions
y_pred = rf_model.predict(X_test)

stats_helper = StatisticsHelper(X, y, rf_model, y_test, y_pred)
stats_helper.show_accuracy()
stats_helper.show_classification_report()
stats_helper.show_confusion_matrix()
stats_helper.show_cross_val_score()
stats_helper.show_roc_auc_score()
# Out:
# ---- Accuracy ----
# Accuracy: 0.8707482993197279
# ------------------
# ---- Classification Report ----
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.97      0.93       741
#          1.0       0.68      0.37      0.48       141
#
#     accuracy                           0.87       882
#    macro avg       0.78      0.67      0.70       882
# weighted avg       0.86      0.87      0.85       882
#
# -------------------------------
# --- Cross Validation Scores ---
# Cross-validated scores: [0.86961451 0.87641723 0.86281179 0.85941043 0.87528345]
# Mean accuracy: 0.8687074829931973
# Standard deviation: 0.006703739455371662
# -------------------------------
# ---- ROC AUC Score ----
# ROC AUC Score: 0.6675280673041032
# ------------------------
